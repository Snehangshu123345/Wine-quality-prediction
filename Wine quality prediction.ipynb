# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1={'a':[1,2,3,4],'b':[6,7,8,9]}
data2={'a':[1,3,7,8],'b':[6,8,22,45]}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)
print(df1['a']!=df2['a'])
print(df1['b']!=df2['b'])
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: a, dtype: bool
# 0    False
# 1     True
# 2     True
# 3     True
# Name: b, dtype: bool

# %%
df1.drop(columns=['a'])
del df2['b']
# Out:
# KeyboardInterrupt

# %%
df2
# Out:
#    a
# 0  1
# 1  3
# 2  7
# 3  8

# %%
# Find rows where values differ in both df1 and df2
diff_rows = (df1 != df2).any(axis=1)

# Create a new DataFrame containing the differing rows from both df1 and df2
diff_df = pd.concat([df1[diff_rows], df2[diff_rows]], keys=['df1', 'df2'])

print(diff_df)
# Out:
#        a   b
# df1 1  2   7
#     2  3   8
#     3  4   9
# df2 1  3   8
#     2  7  22
#     3  8  45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
ndf=df.head(10)
ndf
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
e=[]
for i in ndf.index:
    e.append(f'row-{i}')
e
# Out:
# ['row-0',
#  'row-1',
#  'row-2',
#  'row-3',
#  'row-4',
#  'row-5',
#  'row-6',
#  'row-7',
#  'row-8',
#  'row-9']

# %%
ndf.index=e
ndf
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# row-0            7.4              0.70         0.00             1.9
# row-1            7.8              0.88         0.00             2.6
# row-2            7.8              0.76         0.04             2.3
# row-3           11.2              0.28         0.56             1.9
# row-4            7.4              0.70         0.00             1.9
# row-5            7.4              0.66         0.00             1.8
# row-6            7.9              0.60         0.06             1.6
# row-7            7.3              0.65         0.00             1.2
# row-8            7.8              0.58         0.02             2.0
# row-9            7.5              0.50         0.36             6.1
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# row-0      0.076                 11.0                  34.0   0.9978  3.51
# ...

# %%
# Row 3 to row six
ndf[3:7]
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# row-3           11.2              0.28         0.56             1.9
# row-4            7.4              0.70         0.00             1.9
# row-5            7.4              0.66         0.00             1.8
# row-6            7.9              0.60         0.06             1.6
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# row-3      0.075                 17.0                  60.0   0.9980  3.16
# row-4      0.076                 11.0                  34.0   0.9978  3.51
# row-5      0.075                 13.0                  40.0   0.9978  3.51
# row-6      0.069                 15.0                  59.0   0.9964  3.30
#
#        sulphates  alcohol  quality
# row-3       0.58      9.8        6
# row-4       0.56      9.4        5
# row-5       0.56      9.4        5
# row-6       0.46      9.4        5

# %%
ndf['row-3':'row-6']# Custom Slicing
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# row-3           11.2              0.28         0.56             1.9
# row-4            7.4              0.70         0.00             1.9
# row-5            7.4              0.66         0.00             1.8
# row-6            7.9              0.60         0.06             1.6
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# row-3      0.075                 17.0                  60.0   0.9980  3.16
# row-4      0.076                 11.0                  34.0   0.9978  3.51
# row-5      0.075                 13.0                  40.0   0.9978  3.51
# row-6      0.069                 15.0                  59.0   0.9964  3.30
#
#        sulphates  alcohol  quality
# row-3       0.58      9.8        6
# row-4       0.56      9.4        5
# row-5       0.56      9.4        5
# row-6       0.46      9.4        5

# %%
ndf[0:8:3]
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# row-0            7.4              0.70         0.00             1.9
# row-3           11.2              0.28         0.56             1.9
# row-6            7.9              0.60         0.06             1.6
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# row-0      0.076                 11.0                  34.0   0.9978  3.51
# row-3      0.075                 17.0                  60.0   0.9980  3.16
# row-6      0.069                 15.0                  59.0   0.9964  3.30
#
#        sulphates  alcohol  quality
# row-0       0.56      9.4        5
# row-3       0.58      9.8        6
# row-6       0.46      9.4        5

# %%
ndf['row-0':'row-7':3]
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# row-0            7.4              0.70         0.00             1.9
# row-3           11.2              0.28         0.56             1.9
# row-6            7.9              0.60         0.06             1.6
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# row-0      0.076                 11.0                  34.0   0.9978  3.51
# row-3      0.075                 17.0                  60.0   0.9980  3.16
# row-6      0.069                 15.0                  59.0   0.9964  3.30
#
#        sulphates  alcohol  quality
# row-0       0.56      9.4        5
# row-3       0.58      9.8        6
# row-6       0.46      9.4        5

# %%
ndf.loc['row-0':'row-3':2,'fixed acidity':'alcohol':2]
# Out:
#        fixed acidity  citric acid  chlorides  total sulfur dioxide    pH  \
# row-0            7.4         0.00      0.076                  34.0  3.51
# row-2            7.8         0.04      0.092                  54.0  3.26
#
#        alcohol
# row-0      9.4
# row-2      9.8

# %%
a=ndf.iloc[0:4:2,0:12:2]
a
# Out:
#        fixed acidity  citric acid  chlorides  total sulfur dioxide    pH  \
# row-0            7.4         0.00      0.076                  34.0  3.51
# row-2            7.8         0.04      0.092                  54.0  3.26
#
#        alcohol
# row-0      9.4
# row-2      9.8

# %%
a.loc[3]=[5,4,5,8,7,4]

# %%
a
# Out:
#        fixed acidity  citric acid  chlorides  total sulfur dioxide    pH  \
# row-0            7.4         0.00      0.076                  34.0  3.51
# row-2            7.8         0.04      0.092                  54.0  3.26
# 3                5.0         4.00      5.000                   8.0  7.00
#
#        alcohol
# row-0      9.4
# row-2      9.8
# 3          4.0

# %%
a['new_col1']=100
a
a['new_col2']=[10,21]
a
a['new_col3']=a['new_col2'].apply(lambda x:'Even' if x%2==0 else 'odd')
a
a['col-4']=a['new_col2'].apply(lambda x:x*2)
a
# Out:
#        fixed acidity  citric acid  chlorides  total sulfur dioxide    pH  \
# row-0            7.4         0.00      0.076                  34.0  3.51
# row-2            7.8         0.04      0.092                  54.0  3.26
#
#        alcohol  new_col1  new_col2 new_col3  col-4
# row-0      9.4       100        10     Even     20
# row-2      9.8       100        21      odd     42

# %%
a.assign(new_col5=lambda x:x.new_col1 +x.new_col2)
# Out:
#        fixed acidity  citric acid  chlorides  total sulfur dioxide    pH  \
# row-0            7.4         0.00      0.076                  34.0  3.51
# row-2            7.8         0.04      0.092                  54.0  3.26
#
#        alcohol  new_col1  new_col2 new_col3  col-4  new_col5
# row-0      9.4       100        10     Even     20       110
# row-2      9.8       100        21      odd     42       121

# %%
ndf.loc['row-0':'row-6',['citric acid']]
# Out:
#        citric acid
# row-0         0.00
# row-1         0.00
# row-2         0.04
# row-3         0.56
# row-4         0.00
# row-5         0.00
# row-6         0.06

# %%
ndf.iloc[0:7,[2]]
# Out:
#        citric acid
# row-0         0.00
# row-1         0.00
# row-2         0.04
# row-3         0.56
# row-4         0.00
# row-5         0.00
# row-6         0.06

# %%
sns.set()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
data.describe(include='object')
# Out:
#            State
# count         50
# unique         3
# top     New York
# freq          17

# %%
data.loc[data['State']=='New York']
# Out:
#     R&D Spend  Administration  Marketing Spend     State     Profit
# 0   165349.20       136897.80        471784.10  New York  192261.83
# 3   144372.41       118671.85        383199.62  New York  182901.99
# 5   131876.90        99814.71        362861.36  New York  156991.12
# 8   120542.52       148718.95        311613.29  New York  152211.77
# 15  114523.61       122616.84        261776.23  New York  129917.04
# 17   94657.16       145077.58        282574.31  New York  125370.37
# 19   86419.70       153514.11             0.00  New York  122776.86
# 21   78389.47       153773.43        299737.29  New York  111313.02
# 24   77044.01        99281.34        140574.81  New York  108552.04
# 27   72107.60       127864.55        353183.81  New York  105008.31
# 29   65605.48       153032.06        107138.38  New York  101004.64
# 31   61136.38       152701.92         88218.23  New York   97483.56
# 35   46014.02        85047.44        205517.64  New York   96479.51
# ...

# %%
data.loc[data['R&D Spend']>=15500]
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.loc[(data['R&D Spend'] >= 15500) & (data['State'] == 'New York')][['Marketing Spend','Profit']]
# Out:
#     Marketing Spend     Profit
# 0         471784.10  192261.83
# 3         383199.62  182901.99
# 5         362861.36  156991.12
# 8         311613.29  152211.77
# 15        261776.23  129917.04
# 17        282574.31  125370.37
# 19             0.00  122776.86
# 21        299737.29  111313.02
# 24        140574.81  108552.04
# 27        353183.81  105008.31
# 29        107138.38  101004.64
# 31         88218.23   97483.56
# 35        205517.64   96479.51
# 38        185265.10   81229.06
# 43         35534.17   69758.98

# %%
df=pd.read_csv('QualityPrediction.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df['fixed acidity'][3]
# Out:
# 11.2

# %%
df.at[3,'fixed acidity']
# Out:
# 11.2

# %%
df[['citric acid','fixed acidity','free sulfur dioxide']]
# Out:
#       citric acid  fixed acidity  free sulfur dioxide
# 0            0.00            7.4                 11.0
# 1            0.00            7.8                 25.0
# 2            0.04            7.8                 15.0
# 3            0.56           11.2                 17.0
# 4            0.00            7.4                 11.0
# ...           ...            ...                  ...
# 1594         0.08            6.2                 32.0
# 1595         0.10            5.9                 39.0
# 1596         0.13            6.3                 29.0
# 1597         0.12            5.9                 32.0
# 1598         0.47            6.0                 18.0
#
# [1599 rows x 3 columns]

# %%
df.isnull().sum()/len(df)
# Out:
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# dtype: float64

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
sns.boxplot(x='fixed acidity',data=df)
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
a=df.columns.tolist()

# %%
a
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
sns.boxplot(x='volatile acidity',data=df)
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
sns.barplot(y='fixed acidity',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
sns.barplot(y='volatile acidity',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.barplot(y='citric acid',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='citric acid'>

# %%
sns.barplot(y='residual sugar',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='residual sugar'>

# %%
sns.barplot(y='chlorides',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='chlorides'>

# %%
sns.barplot(y='free sulfur dioxide',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='free sulfur dioxide'>

# %%
sns.barplot(y='total sulfur dioxide',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='total sulfur dioxide'>

# %%
sns.barplot(y='density',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
sns.barplot(y='pH',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %%
sns.barplot(y='sulphates',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='sulphates'>

# %%
sns.barplot(y='alcohol',x='quality',data=df)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
#pH,density
df.drop(columns=['pH','density'],inplace=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df1=df[df['quality']==8]
df1.shape
# Out:
# (18, 10)

# %%
new_index = list(range(18))
df1.index = new_index

# %%
fig, axes = plt.subplots(nrows=len(df1), ncols=1, figsize=(8, 6*len(df1)))

# Iterate through each row and plot pie chart
for i, row in df1.iterrows():
    labels = df1.columns[:9]  # First 11 columns as labels
    sizes = row[:9]          # First 11 values of the row
    axes[i].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
    axes[i].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
    axes[i].set_title(f'Row {i+1}')

plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (1599, 10)

# %%
a
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
sns.boxplot(x='fixed acidity',data=df)
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
threshold = 14

# Cap outliers in column 'A'
df['fixed acidity'] = df['fixed acidity'].apply(lambda x: threshold if x > threshold else x)

# %%
# Calculate quartiles
Q1 = df['fixed acidity'].quantile(0.25)
Q3 = df['fixed acidity'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['fixed acidity'] < lower_bound) | (df['fixed acidity'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['fixed acidity'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
sns.boxplot(x='volatile acidity',data=df)
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
# Calculate quartiles
Q1 = df['volatile acidity'].quantile(0.25)
Q3 = df['volatile acidity'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['volatile acidity'] < lower_bound) | (df['volatile acidity'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['volatile acidity'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
df.shape
# Out:
# (1530, 10)

# %%
sns.boxplot(x='citric acid',data=df)
# Out:
# <Axes: xlabel='citric acid'>

# %%
# Calculate quartiles
Q1 = df['citric acid'].quantile(0.25)
Q3 = df['citric acid'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['citric acid'] < lower_bound) | (df['citric acid'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['citric acid'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
sns.boxplot(x='residual sugar',data=df)
# Out:
# <Axes: xlabel='residual sugar'>

# %%
# Calculate quartiles
Q1 = df['residual sugar'].quantile(0.25)
Q3 = df['residual sugar'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['residual sugar'] < lower_bound) | (df['residual sugar'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['residual sugar'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
df.shape
# Out:
# (1391, 10)

# %%
sns.boxplot(x='chlorides',data=df)
# Out:
# <Axes: xlabel='chlorides'>

# %%
# Calculate quartiles
Q1 = df['chlorides'].quantile(0.25)
Q3 = df['chlorides'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['chlorides'] < lower_bound) | (df['chlorides'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['chlorides'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
df.shape
# Out:
# (1289, 10)

# %%
sns.boxplot(x='free sulfur dioxide',data=df)
# Out:
# <Axes: xlabel='free sulfur dioxide'>

# %%
# Calculate quartiles
Q1 = df['free sulfur dioxide'].quantile(0.25)
Q3 = df['free sulfur dioxide'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['free sulfur dioxide'] < lower_bound) | (df['free sulfur dioxide'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['free sulfur dioxide'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
df.shape
# Out:
# (1264, 10)

# %%
sns.boxplot(x='total sulfur dioxide',data=df)
# Out:
# <Axes: xlabel='total sulfur dioxide'>

# %%
# Calculate quartiles
Q1 = df['total sulfur dioxide'].quantile(0.25)
Q3 = df['total sulfur dioxide'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['total sulfur dioxide'] < lower_bound) | (df['total sulfur dioxide'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['total sulfur dioxide'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
df.shape
# Out:
# (1213, 10)

# %%
sns.boxplot(x='sulphates',data=df)
# Out:
# <Axes: xlabel='sulphates'>

# %%
# Calculate quartiles
Q1 = df['sulphates'].quantile(0.25)
Q3 = df['sulphates'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['sulphates'] < lower_bound) | (df['sulphates'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['sulphates'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
df.shape
# Out:
# (1185, 10)

# %%
sns.boxplot(x='alcohol',data=df)
# Out:
# <Axes: xlabel='alcohol'>

# %%
# Calculate quartiles
Q1 = df['alcohol'].quantile(0.25)
Q3 = df['alcohol'].quantile(0.75)

# Calculate IQR
IQR = Q3 - Q1

# Define lower and upper boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = (df['alcohol'] < lower_bound) | (df['alcohol'] > upper_bound)

# Remove outliers
df = df[~outliers]

# Create boxplot after removing outliers
plt.boxplot(df['alcohol'])
plt.title('Boxplot After Removing Outliers for Fixed Acidity')
plt.show()

# %%
df.shape
# Out:
# (1174, 10)

# %%
from sklearn.preprocessing import StandardScaler
# Selecting columns to scale (except the last column)
cols_to_scale = df.columns[:-1]

# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform selected columns
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

print("DataFrame after scaling:")
print(df)
# Out:
# DataFrame after scaling:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.489689          1.076592    -1.351741       -0.621154  -0.144752
# 1         -0.220007          2.169185    -1.351741        0.955813   1.428091
# 2         -0.220007          1.440789    -1.130764        0.279970   0.999134
# 3          2.072292         -1.472794     1.741932       -0.621154  -0.216245
# 4         -0.489689          1.076592    -1.351741       -0.621154  -0.144752
# ...             ...               ...          ...             ...        ...
# 1594      -1.298736          0.469595    -0.909787       -0.395873   0.856148
# 1595      -1.500997          0.166097    -0.799299        0.054689  -1.145652
# 1596      -1.231315         -0.076702    -0.633567        0.279970  -0.144752
# 1597      -1.500997          0.742743    -0.688811       -0.395873  -0.216245
# 1598      -1.433577         -1.290695     1.244735        3.208623  -0.788188
#
# ...

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1174, dtype: int64

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.489689          1.076592    -1.351741       -0.621154  -0.144752
# 1         -0.220007          2.169185    -1.351741        0.955813   1.428091
# 2         -0.220007          1.440789    -1.130764        0.279970   0.999134
# 3          2.072292         -1.472794     1.741932       -0.621154  -0.216245
# 4         -0.489689          1.076592    -1.351741       -0.621154  -0.144752
# ...             ...               ...          ...             ...        ...
# 1594      -1.298736          0.469595    -0.909787       -0.395873   0.856148
# 1595      -1.500997          0.166097    -0.799299        0.054689  -1.145652
# 1596      -1.231315         -0.076702    -0.633567        0.279970  -0.144752
# 1597      -1.500997          0.742743    -0.688811       -0.395873  -0.216245
# 1598      -1.433577         -1.290695     1.244735        3.208623  -0.788188
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.tree import export_text

# %%
# split the data into training and test for builiding DT model and for prediction
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
dt_clf = DecisionTreeClassifier()
dt_clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# predict
y_pred_train = dt_clf.predict(x_train)
y_pred_test = dt_clf.predict(x_test)

# %%
confusion_matrix(y_test, y_pred_test)
# Out:
# array([[ 1,  2,  6,  0,  0],
#        [ 1, 84, 42,  5,  0],
#        [ 2, 36, 62, 10,  1],
#        [ 0, 10, 15, 14,  3],
#        [ 0,  0,  0,  0,  0]], dtype=int64)

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.25      0.11      0.15         9
#            5       0.64      0.64      0.64       132
#            6       0.50      0.56      0.53       111
#            7       0.48      0.33      0.39        42
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.55       294
#    macro avg       0.37      0.33      0.34       294
# weighted avg       0.55      0.55      0.55       294

# %%
print(accuracy_score(y_train, y_pred_train))
print()
print(accuracy_score(y_test, y_pred_test))
# Out:
# 1.0
#
# 0.5476190476190477

# %%
model_dt_2 = DecisionTreeClassifier(random_state=1,max_depth=2)

model_dt_2.fit(x_train,y_train)

model_dt_2_score_tarin = model_dt_2.score(x_train,y_train)

model_dt_2_score_test = model_dt_2.score(x_test,y_test)

print('Trining Score',model_dt_2_score_tarin)

print('Testing Score',model_dt_2_score_test)
# Out:
# Trining Score 0.5829545454545455
# Testing Score 0.5578231292517006

# %%
model_dt_4 = DecisionTreeClassifier(random_state=1,max_depth=4)

model_dt_4.fit(x_train,y_train)

model_dt_4_score_tarin = model_dt_4.score(x_train,y_train)

model_dt_4_score_test = model_dt_4.score(x_test,y_test)

print('Trining Score',model_dt_4_score_tarin)

print('Testing Score',model_dt_4_score_test)
# Out:
# Trining Score 0.6636363636363637
# Testing Score 0.5578231292517006

# %%
model_dt_6 = DecisionTreeClassifier(random_state=1,max_depth=6)

model_dt_6.fit(x_train,y_train)

model_dt_6_score_tarin = model_dt_6.score(x_train,y_train)

model_dt_6_score_test = model_dt_6.score(x_test,y_test)

print('Trining Score',model_dt_6_score_tarin)

print('Testing Score',model_dt_6_score_test)
# Out:
# Trining Score 0.7522727272727273
# Testing Score 0.5510204081632653

# %%
model_dt_8 = DecisionTreeClassifier(random_state=1,max_depth=8)

model_dt_8.fit(x_train,y_train)

model_dt_8_score_tarin = model_dt_8.score(x_train,y_train)

model_dt_8_score_test = model_dt_8.score(x_test,y_test)

print('Trining Score',model_dt_8_score_tarin)

print('Testing Score',model_dt_8_score_test)
# Out:
# Trining Score 0.8545454545454545
# Testing Score 0.5748299319727891

# %%
model_dt = DecisionTreeClassifier(max_depth=2,criterion='entropy')

model_dt.fit(x_train,y_train)

y_pred_dt = model_dt.predict_proba(x_test)[:,1]
# y_pred_dt

model_dt_score_train = model_dt.score(x_train,y_train)
print(model_dt_score_train)

model_dt_score_test = model_dt.score(x_test,y_test)
print(model_dt_score_test)
# Out:
# 0.5681818181818182
# 0.5544217687074829

# %%
# pip install graphviz
# conda install graphviz
from io import StringIO

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
# from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz

import seaborn as sns

# %%
# %matplotlib inline

import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, cross_val_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier 
from urllib.request import urlopen

# %%
# Cleaning test sets to avoid future warning messages
class_set = x_test.values.ravel() 
test_class_set = y_test.values.ravel()

# %%
fit_rf = RandomForestClassifier(random_state=42)

# %%
np.random.seed(42)
start = time.time()

param_dist = {'max_depth': [2, 3, 4],
              'bootstrap': [True],
              'max_features': ['auto', 'sqrt', 'log2', None],
              }

cv_rf = GridSearchCV(fit_rf, cv = 10,
                     param_grid=param_dist, 
                     n_jobs = 3)

cv_rf.fit(x_train, y_train)
print('Best Parameters using grid search: \n', cv_rf.best_params_)
end = time.time()
print('Time taken in grid search: {0: .2f}'.format(end - start))
# Out:
# Best Parameters using grid search:
#  {'bootstrap': True, 'max_depth': 4, 'max_features': None}
# Time taken in grid search:  51.03

# %%
# Set best parameters given by grid search 
fit_rf.set_params(bootstrap=True,
                  max_features = None, 
                  max_depth = 4)
# Out:
# RandomForestClassifier(max_depth=4, max_features=None, random_state=42)

# %%
fit_rf.set_params(warm_start=True, 
                  oob_score=True)

min_estimators = 15
max_estimators = 1000

error_rate = {}

for i in range(min_estimators, max_estimators + 1):
    fit_rf.set_params(n_estimators=i)
    fit_rf.fit(x_train, y_train)

    oob_error = 1 - fit_rf.oob_score_
    error_rate[i] = oob_error

# %%
 # Convert dictionary to a pandas series for easy plotting 
oob_series = pd.Series(error_rate)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.set_facecolor('#fafafa')

oob_series.plot(kind='line',color = 'red')
plt.axhline(0.055, color='#875FDB',linestyle='--')
plt.axhline(0.05, color='#875FDB',linestyle='--')
plt.xlabel('n_estimators')
plt.ylabel('OOB Error Rate')
plt.title('OOB Error Rate Across various Forest sizes \n(From 15 to 1000 trees)')
# Out:
# Text(0.5, 1.0, 'OOB Error Rate Across various Forest sizes \n(From 15 to 1000 trees)')

# %%
print('OOB Error rate for 400 trees is: {0:.5f}'.format(oob_series[40]))
# Out:
# OOB Error rate for 400 trees is: 0.40033

# %%
# Refine the tree via OOB Output
fit_rf.set_params(n_estimators=40,
                  bootstrap = True,
                  oob_score=False)
# Out:
# RandomForestClassifier(max_depth=4, max_features=None, n_estimators=40,
#                        random_state=42, warm_start=True)

# %%
accuracy_rf = fit_rf.score(x_test, y_test)

print("Here is our accuracy on the test set:\n {0:.3f}"\
      .format(accuracy_rf))
# Out:
# Here is our accuracy on the test set:
#  0.560

# %%
from sklearn.svm import SVC
from sklearn import metrics
svc = SVC()
svc.fit(x_train,y_train)
y_pred = svc.predict(x_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.6122448979591837

# %%
svc = SVC(kernel='linear')
svc.fit(x_train,y_train)
y_pred = svc.predict(x_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.5952380952380952

# %%
svc = SVC(kernel='poly')
svc.fit(x_train,y_train)
y_pred = svc.predict(x_test)
print('Accuracy Score:')
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score:
# 0.5850340136054422

# %%
# cross-validation import from sklearn
from sklearn.model_selection import cross_val_score

C_range = list(range(1,25))
acc_score=[]
for c in C_range:
    svc = SVC(kernel='linear',C=c)
    scores = cross_val_score(svc,x,y,cv=10,scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.5870491090830073, 0.5861944082283065, 0.584492249746487, 0.5862016514558887, 0.584492249746487, 0.584492249746487, 0.584492249746487, 0.584492249746487, 0.584492249746487, 0.5862016514558887, 0.5862016514558887, 0.5870491090830073, 0.5862016514558887, 0.5870491090830073, 0.5862016514558887, 0.5862016514558887, 0.5862016514558887, 0.5862016514558887, 0.5870491090830073, 0.5862016514558887, 0.5862016514558887, 0.5862016514558887, 0.5862016514558887, 0.5862016514558887]

# %%
gamma_range = [0.0001,0.001,0.01,0.1,1,10,100]
acc_score = []
for g in gamma_range:
    svc = SVC(kernel='rbf',gamma=g)
    scores = cross_val_score(svc,x,y,cv=10,scoring='accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.4241923801245835, 0.5785310734463277, 0.5887150514269159, 0.6066058235549762, 0.539272779950746, 0.43441257424308277, 0.4318339852238157]

# %%
# Python Solution 
# Import packages
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
# Init the Gaussian Classifier
model = GaussianNB()

# Train the model
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# Predict Output 
pred = model.predict(x_test)
print(pred[:150])
# Out:
# [5 6 6 5 5 7 5 7 5 5 5 6 6 6 5 5 7 5 6 6 5 6 6 7 7 6 5 5 6 5 7 5 6 7 5 6 5
#  5 6 6 5 5 7 5 6 5 5 7 6 6 5 5 5 5 5 6 6 5 5 5 6 5 6 6 6 7 6 5 5 5 6 6 6 5
#  5 6 6 6 6 5 5 6 6 7 7 5 7 5 6 6 6 5 6 6 5 5 7 5 5 5 6 5 6 5 6 6 5 6 5 5 4
#  5 5 6 6 5 6 5 6 5 5 6 6 5 6 5 7 6 5 6 7 5 6 5 5 6 7 5 5 5 7 5 5 6 5 5 7 5
#  6 6]

# %%
# Plot Confusion Matrix
#plt.figure(figsize=(10,8))
mat = confusion_matrix(pred, y_test)
names = np.unique(pred)
sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=names, yticklabels=names)
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.plot()
# Out:
# []

# %%
# Importing the dependancies
from sklearn import metrics
# Predicted values
y_pred = pred
# Actual values
y_act = y_test
# Printing the confusion matrix
# The columns will show the instances predicted for each label,
# and the rows will show the actual number of instances for each label.
print(metrics.confusion_matrix(pred, y_test))
# Printing the precision and recall, among other metrics
print(metrics.classification_report(pred, y_test))
# Out:
# [[ 1  3  1  0]
#  [ 6 96 46  3]
#  [ 2 30 48 17]
#  [ 0  3 16 22]]
#               precision    recall  f1-score   support
#
#            4       0.11      0.20      0.14         5
#            5       0.73      0.64      0.68       151
#            6       0.43      0.49      0.46        97
#            7       0.52      0.54      0.53        41
#
#     accuracy                           0.57       294
#    macro avg       0.45      0.47      0.45       294
# weighted avg       0.59      0.57      0.58       294

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pred = knn.predict(x_test)

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[ 0  0  0  0  0  0]
#  [ 1  0  6  2  0  0]
#  [ 1  3 87 36  3  2]
#  [ 0  5 35 61  8  2]
#  [ 0  0  5 18 17  2]
#  [ 0  0  0  0  0  0]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         9
#            5       0.65      0.66      0.66       132
#            6       0.52      0.55      0.54       111
#            7       0.61      0.40      0.49        42
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.56       294
#    macro avg       0.30      0.27      0.28       294
# weighted avg       0.58      0.56      0.57       294

# %%
accuracy_rate = []

# May take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    score=cross_val_score(knn,x,y,cv=10)
    accuracy_rate.append(score.mean())

# %%
accuracy_rate
# Out:
# [0.4718166014776185,
#  0.4906055338258728,
#  0.4838186295813415,
#  0.5400478053020425,
#  0.5324786324786325,
#  0.5443864986237867,
#  0.5435535274518325,
#  0.5596914385049978,
#  0.5401202375778646,
#  0.5443720121686223,
#  0.5384325655512096,
#  0.5503766478342749,
#  0.5512241054613936,
#  0.560589598725192,
#  0.5571780385339707,
#  0.5546718817905258,
#  0.5563740402723452,
#  0.5622845139794291,
#  0.5538244241634072,
#  0.55124583514414,
#  0.5487179487179488,
#  0.5461393596986817,
#  0.5529479936259596,
#  0.5563305809068521,
#  0.5640228885991597,
#  0.5605895987251919,
#  0.5699985513544835,
#  0.5657757496740548,
#  0.5691800666376936,
#  0.5674561784731276,
#  0.5716934666087208,
#  0.562313486889758,
#  0.5665580182529334,
#  0.5648196436332029,
#  0.5614370563523106,
#  0.5571997682167174,
#  0.5589381428364478,
#  0.5563595538171808,
#  0.5597493843256555]

# %%
plt.figure(figsize=(10,6))
# plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
#         markerfacecolor='red', markersize=10)
# plt.title('Error Rate vs. K Value')
# plt.xlabel('K')
# plt.ylabel('Error Rate')

plt.plot(range(1,40),accuracy_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Accuracy Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy Rate')
# Out:
# Text(0, 0.5, 'Accuracy Rate')
